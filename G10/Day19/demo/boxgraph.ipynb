# %%
import matplotlib.pyplot as plt

heights_no_outlier = [160, 162, 163, 165, 166, 167, 168, 168, 169, 170, 171, 172, 173, 174, 175]

heights_with_outlier = [140, 160, 162, 163, 165, 166, 167, 168, 168, 169, 170, 171, 172, 190, 195]

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].boxplot(heights_no_outlier, orientation='vertical')
axes[0].set_title("Class A (No Outliers)")
axes[0].set_ylabel("Height (cm)")

axes[1].boxplot(heights_with_outlier, orientation='vertical')
axes[1].set_title("Class B (With Outliers)")
axes[1].set_ylabel("Height (cm)")

plt.suptitle("Boxplot of Student Heights (2 Classes)", fontsize=14)
plt.show()

# %%
import numpy as np
students = ['A', 'B', 'C', 'D', 'E']
math_scores = [88, 92, 79, 93, 85]
science_scores = [75, 89, 95, 80, 70]

# Simple Bar Plot
# plt.bar(students, math_scores, label="Math", color="skyblue")
# plt.bar(students, science_scores, label="Science", color="salmon", alpha=0.7)
x = np.arange(len(students))   # [0,1,2,3,4]
width = 0.35                   # width of each bar

# Bar Plot (side-by-side)
plt.bar(x - width/2, math_scores, width, label="Math", color="skyblue")
plt.bar(x + width/2, science_scores, width, label="Science", color="salmon")

plt.title("Math vs Science Scores (Bar Plot)")
plt.xlabel("Students")
plt.ylabel("Scores")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    "Math": [88, 92, 79, 93, 85],
    "Science": [75, 89, 95, 80, 70]
}
students = ['A', 'B', 'C', 'D', 'E']

df = pd.DataFrame(data, index=students)

# Plot directly
df.plot(kind="bar", figsize=(12,12))
plt.title("Math vs Science Scores (Bar Plot)")
plt.xlabel("Students")
plt.ylabel("Scores")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years = np.arange(2015, 2025)
admissions = np.array([45, 52, 48, 60, 75, 68, 82, 77, 90, 72])

#print(years)
# Find the highest point and lowest point
year_max, val_max = years[admissions.argmax()], admissions[admissions.argmax()]
year_min, val_min = years[admissions.argmin()], admissions[admissions.argmin()]

# Create plot in form of line chart
plt.subplots(figsize=(10, 5))
plt.plot(years, admissions, marker='o', linestyle='-', linewidth=2, color='tab:blue', label='Admissions')

# Annotate highest point (green arrow and green text)
plt.annotate(
    f"Highest\n{year_max}: {val_max}",
    xy=(year_max, val_max),
    xytext=(year_max, val_max + 10),
    arrowprops=dict(facecolor='green', edgecolor='green', arrowstyle='->', linewidth=1.5),
    color='green',
    fontsize=10,
    ha='center'
)

# Annotate lowest point (red arrow and red text)
plt.annotate(
    f"Lowest\n{year_min}: {val_min}",
    xy=(year_min, val_min),
    xytext=(year_min, val_min + 10),
    arrowprops=dict(facecolor='red', edgecolor='red', arrowstyle='->', linewidth=1.5),
    color='red',
    fontsize=10,
    ha='center'
)
plt.grid(True, linestyle='--', alpha=1)

min_year, max_year = years.min(), years.max()
min_adm, max_adm   = admissions.min(), admissions.max()

plt.xlim(min_year - 1, max_year + 1)
plt.ylim(min_adm - 10, max_adm + 10)

for x, y in zip(years, admissions):
    # place text slightly to the right and up in data units
    plt.text(x - 0.2, y - 3.0, f"({x}, {y})", fontsize=8, color = 'maroon')

# Labels, title, legend
plt.xlabel("Year")
plt.ylabel("Number of Admissions")
plt.title("Admissions per Year (2015–2024)")
plt.legend()

plt.tight_layout()
plt.show()

# %%
from matplotlib import colormaps
print(list(colormaps))
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 
# ...

# %%
import numpy as np
from matplotlib import colormaps
#Get the inbuilt object that for 'viridis' colormap. Viridis is continuous colormap, meaning it smoothly interpolates colors for any value between 0 and 1.
viridis = colormaps['viridis']

# 6 points between 0 and 1
values = np.linspace(0, 1, 6)  
#get list of colors from array
colors = [viridis(v) for v in values]

#create a figure
plt.figure(figsize=(8, 1))
for i, c in enumerate(colors):
    #fill a rectangular area with the color specified 
    #[i, i+1] is the x co-ordinates
    #0, 1 is the x co-ordinates
    plt.fill_between([i, i+1], 0, 1, color=c)
    #frome the text
    plt.text(i+0.5, 0.5, f"{values[i]:.2f}", ha="center", va="center", color="white", fontsize=12)

#to disappear the axes
plt.axis("off")
#set the title of the plot
plt.title("Viridis values at [0.0 to 1.0]", fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt

countries = ["Argentina", "Sweden", "South Africa", "Spain", "China", "Uganda", "Japan", "India", 'Mauritius']
densities = [44, 67, 140, 250, 390, 640, 880, 1260, 1650]

# Create scatter plot with viridis colormap
# plt.figure(figsize=(10,6))
plt.subplots(figsize=(10,6))
sc = plt.scatter(countries, densities, c=densities, cmap="viridis", s=200, edgecolor="black", marker="o"
)

#code to add density as text for marker
for index in range(len(densities)):
  plt.text(countries[index], densities[index] + 50, densities[index], fontsize=8, color = 'black', ha = 'center')
    

# Add colorbar
cbar = plt.colorbar(sc)
cbar.set_label("Population Density (per km²)", fontsize=12)

# Labels and title
plt.xticks(rotation=45)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Population Density", fontsize=12)
plt.title("Population Density Across Selected Countries", fontsize=14, fontweight="bold")

# Adjust y-axis
plt.ylim(0, 1750)
plt.show()
