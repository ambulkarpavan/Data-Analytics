# %%
import re

text= 'a.b$$$'
pattern = '\\.'
print(len(re.findall(pattern, text)))
# Out:
# 1
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\pavan\AppData\Local\Temp\ipykernel_28216\2721427694.py:4: SyntaxWarning: invalid escape sequence '\.'
#   pattern = '\.'
