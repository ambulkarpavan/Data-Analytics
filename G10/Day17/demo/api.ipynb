# %%
import numpy as np
import pandas as pd
import requests
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print("The URL is:", r.url)
print("The JSON is:", r.json())
print("The status code is:", r.status_code)
# Out:
# The URL is: https://httpbin.org/get?key1=value1&key2=value2
# The JSON is: {'args': {'key1': 'value1', 'key2': 'value2'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.4', 'X-Amzn-Trace-Id': 'Root=1-6894785b-0c96d5f83d87d5ee35807d95'}, 'origin': '136.233.11.130', 'url': 'https://httpbin.org/get?key1=value1&key2=value2'}
# The status code is: 200

# %%
response = requests.get('https://jsonplaceholder.typicode.com/posts/1')
#convert the response to the json object
data = response.json()
print(data)
dFrame1 = pd.DataFrame(data, index=[0])
print(dFrame1)
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...

# %%
print("Indexes:",dFrame1.index)
print("Columns:",dFrame1.columns)
print("Values:",dFrame1.values)
# Out:
# Indexes: Index([0], dtype='int64')
# Columns: Index(['userId', 'id', 'title', 'body'], dtype='object')
# Values: [[1 1
#   'sunt aut facere repellat provident occaecati excepturi optio reprehenderit'
#   'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto']]

# %%
print("Id:", dFrame1['id'].to_string(index = False))
# Out:
# Id: 1

# %%
dFrame1 = pd.DataFrame(
  {
    'age' : [5, 6, np.nan],
    'born' : [pd.NaT, pd.Timestamp('1939-05-27'), pd.Timestamp('1940-04-25')],
    'name' : ['Alfred', 'Batman', ''],
    'toy' : [None, 'Batmobile', 'Joker']
  }
)
print("The dataframe dFrame1 is\n", dFrame1, sep = "")
print("\nThe dataframe against the missing values is\n", dFrame1.isna(), sep = "")
print("\nMissing value count in every column is\n", dFrame1.isnull().sum(), sep = "")
print("\nMissing value count in every row is\n", dFrame1.isnull().sum(axis = 1), sep = "")
print("\nMissing value count in whole dataframe is", dFrame1.isnull().sum().sum())
# Out:
# The dataframe dFrame1 is
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker
#
# The dataframe against the missing values is
#      age   born   name    toy
# 0  False   True  False   True
# 1  False  False  False  False
# 2   True  False  False  False
#
# Missing value count in every column is
# age     1
# born    1
# name    0
# toy     1
# dtype: int64
#
# Missing value count in every row is
# 0    2
# 1    0
# 2    1
# dtype: int64
#
# Missing value count in whole dataframe is 3

# %%
dFrame7 = pd.DataFrame(
  [
    (0.0, np.nan, -1.0, 1.0),
    (np.nan, 2.0, np.nan, np.nan),
    (2.0, 3.0, np.nan, 9.0),
    (np.nan, 4.0, -4.0, 16.0)
  ],
  columns=list('abcd')
)
print("The dFrame7 is\n",dFrame7,sep = "")
dFrame8 = dFrame7.fillna(dFrame7.interpolate())
print("\nThe dFrame7 with linear interpolated value instead of missing value is\n",dFrame8,sep = "")
# Out:
# The dFrame7 is
#      a    b    c     d
# 0  0.0  NaN -1.0   1.0
# 1  NaN  2.0  NaN   NaN
# 2  2.0  3.0  NaN   9.0
# 3  NaN  4.0 -4.0  16.0
#
# The dFrame7 with linear interpolated value instead of missing value is
#      a    b    c     d
# 0  0.0  NaN -1.0   1.0
# 1  1.0  2.0 -2.0   5.0
# 2  2.0  3.0 -3.0   9.0
# 3  2.0  4.0 -4.0  16.0

# %%
ser = pd.Series([1, 2, 3, 3])
plot = ser.plot(kind='hist', title="My plot")

# %%
dFrame1 = pd.DataFrame(
  {
    'length': [1.5, 0.5, 1.2, 0.9, 3],
    'width': [0.7, 0.2, 0.15, 0.2, 1.1]
  },
    index=['pig', 'rabbit', 'duck', 'chicken', 'horse']
)
plot = dFrame1.plot(title="DataFrame Plot")
