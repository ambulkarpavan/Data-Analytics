# %%
import numpy as np
a, b = np.array([[2, 4, 6], [8, 10, 12]]), np.array([[1, 2], [3, 4], [5, 6]])
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 a, b = np.array([[2, 4, 6], [8, 10, 12]]), np.array([[1, 2], [3, 4], [5, 6]])
# ----> 3 print(a + b)
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)
